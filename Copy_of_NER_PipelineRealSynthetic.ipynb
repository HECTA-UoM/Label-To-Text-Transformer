# %% [markdown]
# ### Set Up

# %%
# installing Med7 (GLOVE and roberta embeddings) and it's related libraries
# !python -m pip install jedi --quiet
# !python -m pip install -U wheel pip setuptools pip install spacy==3.4.4 pip install spacy-transformers==1.1.9 --quiet
# !python -m pip install https://huggingface.co/kormilitzin/en_core_med7_lg/resolve/main/en_core_med7_lg-any-py3-none-any.whl --quiet
# !python -m pip install https://huggingface.co/kormilitzin/en_core_med7_trf/resolve/main/en_core_med7_trf-any-py3-none-any.whl --quiet

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# CD to Drive Directory for imports
import sys
sys.path.append('drive/MyDrive/SynDa_Health/DownstreamNERTask')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import pickle
import ast

from tqdm import tqdm

import spacy

from Modules.label_parser import ner_parser
from Modules.extract_ner_datasets import extract_data
from Modules.finetune_spacy import load_valid_data, load_test_data, train_ner, evaluate_ner

# %%
# input_paths = ["Real", "LT3", "T5"]
input_paths = ["RealSynthetic"]
specific_path = None
OUT_PATH = "drive/MyDrive/SynDa_Health/DatasetAnalysis/Generations/Results"

EPOCHS = 10

# %% [markdown]
# ### Train Model

# %%
# def prepare_dataset(specific_path=None):
#     global input_paths

#     if specific_path:
#         input_paths = [specific_path]

#     for input_path in input_paths:

#         path = "drive/MyDrive/SynDa_Health/DatasetAnalysis/Generations" + input_path

#         for split_path in ['train', 'valid', 'test']:
#             df = read_text_into_dataframe(path + f"/{split_path}_descriptions.txt")

#             parsed_data = pd.concat([ner_parser(instruction) for instruction in df['instructions']])
#             parsed_data.reset_index(drop=True, inplace=True)
#             df_with_entities = pd.concat([df, parsed_data], axis=1)

#             data = extract_data(df_with_entities)

#             with open(path + f'/{split_path}_data.pkl', 'wb') as f:
#                 pickle.dump(data, f)

# %%
def prepare_dataset(specific_path=None):
    global input_paths

    if specific_path:
        input_paths = [specific_path]

    for input_path in ["Real"]:

        path = "drive/MyDrive/SynDa_Health/DatasetAnalysis/Generations/" + input_path

        # df = read_text_into_dataframe(path + f"/{input_path}-Training-5xGenerations.txt")
        with open(path + f"/train_descriptions.txt") as f:
          lines = f.readlines()

        # Split the data into lines
        # lines = data.split('\n')

        # Create a DataFrame with one column
        df = pd.DataFrame({'instructions': lines})

        # Display the DataFrame
        parsed_data = pd.concat([ner_parser(instruction) for instruction in df['instructions']])
        parsed_data.reset_index(drop=True, inplace=True)
        df_with_entities = pd.concat([df, parsed_data], axis=1)

        data = extract_data(df_with_entities)

        with open(path + f'/5xGenerationsReal_data.pkl', 'wb') as f:
            pickle.dump(data, f)

# %%
def prepare_dataset(specific_path=None):
    global input_paths

    if specific_path:
        input_paths = [specific_path]

    for input_path in ["LT3"]:

        path = "drive/MyDrive/SynDa_Health/DatasetAnalysis/Generations/" + input_path
        with open(path + f"/{input_path}-Testing-5xGenerations.txt", 'r') as fp:
            medications = ast.literal_eval(fp.read())

        instructions = []
        for key in medications:
            for value in medications[key]:
                instructions.append(value)

        df = pd.DataFrame(instructions, columns=["instructions"])
        # df = read_text_into_dataframe(path + f"/{input_path}-Training-5xGenerations.txt")
        parsed_data = pd.concat([ner_parser(instruction) for instruction in df['instructions']])
        parsed_data.reset_index(drop=True, inplace=True)
        df_with_entities = pd.concat([df, parsed_data], axis=1)

        data = extract_data(df_with_entities)
        with open(path + f'/5xGenerationsSynthetic_data.pkl', 'wb') as f:
            pickle.dump(data, f)

# %%
if __name__ == "__main__":
    prepare_dataset()

# %%
def filter_data(data, keep_count=1):
    """
    Filters the data based on the first word of the first element of the tuple.
    Keeps only 'keep_count' number of entries for tuples with the same starting word.

    Parameters:
    - data: A list of tuples.
    - keep_count: Number of entries to keep for tuples with the same starting word.

    Returns:
    - A filtered list of tuples.
    """
    filtered_data = []
    seen = {}

    for item in data:
        # Get the starting word from the first element of the tuple.
        starting_word = item[0].split()[0]

        # Check if we've seen this word before.
        if starting_word in seen:
            seen[starting_word] += 1
            if seen[starting_word] <= keep_count:
                filtered_data.append(item)
        else:
            seen[starting_word] = 1
            filtered_data.append(item)

    return filtered_data

# %%
def filter_data_proportional(data, proportion=0.2):
    """
    Filters the data based on the first word of the first element of the tuple.
    Keeps a proportional number of entries for tuples with the same starting word.

    Parameters:
    - data: A list of tuples.
    - proportion: Proportion of entries to keep for tuples with the same starting word.

    Returns:
    - A filtered list of tuples.
    """
    filtered_data = []

    # Count the occurrences of each starting word
    word_count = {}
    for item in data:
        starting_word = item[0].split()[0]
        word_count[starting_word] = word_count.get(starting_word, 0) + 1

    # Calculate the number of entries to keep for each starting word
    keep_count = {word: int(count * proportion) for word, count in word_count.items()}

    # Make sure at least one item is kept for each starting word
    for word in keep_count:
        keep_count[word] = max(1, keep_count[word])

    seen = {}
    for item in data:
        starting_word = item[0].split()[0]

        if starting_word in seen:
            seen[starting_word] += 1
            if seen[starting_word] <= keep_count[starting_word]:
                filtered_data.append(item)
        else:
            seen[starting_word] = 1
            filtered_data.append(item)

    return filtered_data

# %%
def oversample_data(data, oversampling_factor):
    oversampled_data = []
    for _ in range(oversampling_factor):
        oversampled_data.extend(data)
    return oversampled_data

# %%
def train_evaluate(epochs=1, param=0.2, specific_path=None, squeeze=False, oversampling_factor=1):
    global input_paths

    if specific_path:
        input_paths = [specific_path]

    keep_count = 5
    proportional = True

    for input_path in input_paths:

        path = "drive/MyDrive/SynDa_Health/Dataset/NER_Splits/"

        # Load real and synthetic data
        real_data = load_valid_data("drive/MyDrive/SynDa_Health/DatasetAnalysis/Generations", "/Real/5xGenerationsReal_data.pkl")
        synthetic_data = load_valid_data("drive/MyDrive/SynDa_Health/DatasetAnalysis/Generations", "/LT3/5xGenerationsSynthetic_data.pkl")

        # Use filter_data_proportional to filter synthetic data
        if param > 0:
            filtered_synthetic_data = filter_data_proportional(synthetic_data, param)
        else:
            filtered_synthetic_data = []

        # Concatenate real and filtered synthetic data
        valid_data = real_data + filtered_synthetic_data

        # Oversample the data
        if oversampling_factor > 1:
            valid_data = oversample_data(valid_data, oversampling_factor)

        test_data = load_test_data(path)

        nlp = spacy.load('en_core_web_sm')
        ner = nlp.get_pipe("ner")

        train_ner(nlp, ner, valid_data, epochs=epochs)
        results = evaluate_ner(nlp, test_data)

        df = pd.DataFrame(results).T

        df.to_csv(OUT_PATH + str(param) + "FinalSpacyRealSynthetic" + input_path + (f"squeeze{keep_count}" if squeeze else "") + (f"{param}proportional" if proportional else "") + ".csv")

        return df

# %%
if __name__ == "__main__":
    dfs = []
    for proportion in tqdm(range(5)):
        dfs.append(train_evaluate(epochs=EPOCHS, squeeze=False, param=proportion))

    with open("drive/MyDrive/SynDa_Health/DatasetAnalysis/Generations/dfsRealSynthetic.pkl", "wb") as pickle_file:
        pickle.dump(dfs, pickle_file)

from google.colab import runtime
runtime.unassign()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "metoprolol succinate xl 50 mg PO DAILY RX *metopro..." with entities "[(0, 20, 'DRUG'), (24, 29, 'STRENGTH'), (72, 78, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "clonidine 0.3 mg/24 hr Patch Weekly Sig: One (1) P..." with entities "[(0, 9, 'DRUG'), (10, 16, 'STRENGTH'), (23, 28, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "hydromorphone (Dilaudid) 2 mg PO Q4H:PRN Pain RX *..." with entities "[(0, 13, 'DRUG'), (25, 29, 'STRENGTH'), (91, 97, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "clopidogrel 75 mg PO DAILY RX *clopidogrel 75 mg 1..." with entities "[(0, 11, 'DRUG'), (12, 17, 'STRENGTH'), (51, 57, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "tamsulosin 0.4 mg PO DAILY RX *tamsulosin 0.4 mg 1..." with entities "[(0, 10, 'DRUG'), (11, 17, 'STRENGTH'), (51, 58, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "insulin syringe-needle U-100 1 mL 26 x [**2-14**] ..." with entities "[(0, 15, 'DRUG'), (25, 28, 'STRENGTH'), (100, 103,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amiodarone hcl 200 mg Tablet Sig: Two (2) Tablet P..." with entities "[(0, 14, 'DRUG'), (15, 21, 'STRENGTH'), (22, 28, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient [**Name (NI) **] Work PT, PTT, INR, Che..." with entities "[(0, 10, 'DRUG'), (52, 53, 'STRENGTH'), (70, 82, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "metolazone 2.5 mg Tablet Sig: One (1) Tablet PO DA..." with entities "[(0, 10, 'DRUG'), (11, 17, 'STRENGTH'), (18, 24, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "clonidine 0.1 mg/24 hr Patch Weekly Sig: One (1) P..." with entities "[(0, 9, 'DRUG'), (10, 16, 'STRENGTH'), (23, 28, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "docusate sodium 100 mg PO BID RX *docusate sodium ..." with entities "[(0, 15, 'DRUG'), (16, 22, 'STRENGTH'), (59, 66, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 5 mg Tablet Sig: One (1) Tablet PO DAIL..." with entities "[(0, 10, 'DRUG'), (11, 15, 'STRENGTH'), (16, 22, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "sertraline 50 mg Tablet Sig: Five (5) Tablet PO DA..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (17, 23, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "cyanocobalamin (vitamin B-12) 1,000 mcg Tablet Sig..." with entities "[(0, 14, 'DRUG'), (26, 28, 'STRENGTH'), (40, 46, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D2 50,000 unit Capsule Sig: One (1) Capsul..." with entities "[(0, 9, 'DRUG'), (11, 17, 'STRENGTH'), (23, 30, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "voriconazole 200 mg PO Q12H RX *voriconazole 200 m..." with entities "[(0, 12, 'DRUG'), (13, 19, 'STRENGTH'), (54, 60, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "novolin 70/30 InnoLet 100 unit/mL (70-30) Insulin ..." with entities "[(0, 7, 'DRUG'), (8, 10, 'STRENGTH'), (50, 53, 'FO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nafcillin in D2.4W 2 g/100 mL Piggyback Sig: Two (..." with entities "[(0, 12, 'DRUG'), (14, 15, 'STRENGTH'), (77, 90, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "hexavitamin     tablet [**Hospital1 **]: One (1) T..." with entities "[(0, 11, 'DRUG'), (34, 35, 'STRENGTH'), (16, 22, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin B-12 1,000 mcg Tablet Sig: One (1) Tablet ..." with entities "[(0, 9, 'DRUG'), (10, 12, 'STRENGTH'), (23, 29, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient lab Work Please obtain weekly CBC, BUN/..." with entities "[(0, 14, 'DRUG'), (114, 115, 'STRENGTH'), (34, 40,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "torsemide 100 mg PO DAILY Hold for SBP <90 RX *tor..." with entities "[(0, 9, 'DRUG'), (10, 16, 'STRENGTH'), (66, 72, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "pantoprazole 40 mg PO Q24H RX *pantoprazole 40 mg ..." with entities "[(0, 12, 'DRUG'), (13, 18, 'STRENGTH'), (52, 58, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amoxicillin 500 mg PO Q8H RX *amoxicillin 500 mg 1..." with entities "[(0, 11, 'DRUG'), (12, 18, 'STRENGTH'), (51, 57, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D-3 400 unit Tablet [**Hospital1 **]: One ..." with entities "[(0, 9, 'DRUG'), (10, 11, 'STRENGTH'), (21, 27, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "duoneb 0.5 mg-3 mg(2.5 mg base)/3 mL Solution for ..." with entities "[(0, 6, 'DRUG'), (7, 13, 'STRENGTH'), (37, 45, 'FO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 40 mg PO DAILY Duration: 2 Days Tapered..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (86, 92, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amlodipine 5 mg Tablet Sig: Two (2) Tablet PO DAIL..." with entities "[(0, 10, 'DRUG'), (11, 15, 'STRENGTH'), (16, 22, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient [**Month/Day/Year **] Work Please check..." with entities "[(0, 10, 'DRUG'), (56, 58, 'STRENGTH')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amylase-lipase-protease 33,200-10,000- 37,500 unit..." with entities "[(0, 7, 'DRUG'), (24, 37, 'STRENGTH'), (51, 58, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient lab Work Weekly Chem-7, CBC with DIFF, ..." with entities "[(0, 14, 'DRUG'), (32, 33, 'STRENGTH'), (20, 26, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amlodipine 10 mg PO once a day. Disp:*30 Tablet(s)..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (41, 47, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acetaminophen 325-650 mg PO Q6H:PRN pain RX *aceta..." with entities "[(0, 13, 'DRUG'), (14, 24, 'STRENGTH'), (68, 74, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient lab Work Patient will require once week..." with entities "[(0, 14, 'DRUG'), (63, 64, 'STRENGTH')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "mycophenolate mofetil 250 mg Capsule [**Hospital1 ..." with entities "[(0, 21, 'DRUG'), (22, 28, 'STRENGTH'), (29, 36, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nafcillin in D2.4W 2 gram/100 mL Piggyback [**Tele..." with entities "[(0, 12, 'DRUG'), (14, 15, 'STRENGTH'), (100, 113,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "tamsulosin 0.4 mg PO HS RX *tamsulosin 0.4 mg 1 ca..." with entities "[(0, 10, 'DRUG'), (11, 17, 'STRENGTH'), (48, 55, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D-3 400 unit Tablet, Chewable Sig: [**12-1..." with entities "[(0, 9, 'DRUG'), (10, 11, 'STRENGTH'), (21, 27, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "insulin Syringes Low dose U-100 syringes 25-26 gau..." with entities "[(0, 16, 'DRUG'), (28, 31, 'STRENGTH')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D3  Oral
# " with entities "[(0, 9, 'DRUG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ciprofloxacin hcl 500 mg PO Q12H Duration: 7 Days ..." with entities "[(0, 17, 'DRUG'), (18, 24, 'STRENGTH'), (85, 91, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "hydralazine 75 mg PO Q8H please hold for SBP <100 ..." with entities "[(0, 11, 'DRUG'), (12, 17, 'STRENGTH'), (76, 82, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 60 mg PO DAILY RX *prednisone 10 mg 1 T..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (49, 55, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "montelukast sodium 10 mg PO DAILY RX *Singulair 10..." with entities "[(0, 18, 'DRUG'), (19, 24, 'STRENGTH'), (56, 62, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "furosemide 40 mg Tablet Sig: One (1) Tablet PO DAI..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (17, 23, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "metoprolol tartrate 12.5 mg PO BID hold for SBP < ..." with entities "[(0, 19, 'DRUG'), (20, 27, 'STRENGTH'), (108, 114,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D-3 1,000 unit Tablet, Chewable Sig: One (..." with entities "[(0, 9, 'DRUG'), (10, 11, 'STRENGTH'), (23, 29, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "omeprazole 20 mg PO BID RX *omeprazole 20 mg 1 cap..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (47, 54, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "pantoprazole 40 mg PO Q12H RX *pantoprazole 40 mg ..." with entities "[(0, 12, 'DRUG'), (13, 18, 'STRENGTH'), (52, 58, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 20 mg PO DAILY Duration: 2 Days Tapered..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (86, 92, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acyclovir 400 mg PO Q8H RX *acyclovir 400 mg 1 tab..." with entities "[(0, 9, 'DRUG'), (10, 16, 'STRENGTH'), (47, 53, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 60 mg PO DAILY Duration: 2 Days Tapered..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (96, 102, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#
#  10%|█         | 1/10 [01:33<14:00, 93.37s/it]
#  20%|██        | 2/10 [03:25<13:56, 104.61s/it]
#  30%|███       | 3/10 [05:20<12:44, 109.15s/it]
#  40%|████      | 4/10 [07:14<11:07, 111.18s/it]
#  50%|█████     | 5/10 [09:09<09:22, 112.59s/it]
#  60%|██████    | 6/10 [11:05<07:34, 113.55s/it]
#  70%|███████   | 7/10 [13:00<05:42, 114.03s/it]
#  80%|████████  | 8/10 [14:54<03:48, 114.09s/it]
#  90%|█████████ | 9/10 [16:49<01:54, 114.46s/it]
# 100%|██████████| 10/10 [18:44<00:00, 112.50s/it]
#  20%|██        | 1/5 [19:05<1:16:23, 1145.83s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "levothyroxine 100 mcg PO DAILY RX* levothyroxine 2..." with entities "[(0, 13, 'DRUG'), (14, 21, 'STRENGTH'), (56, 62, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acetaminophen 650 mg PO Q6H RX* acetaminophen 650 ..." with entities "[(0, 13, 'DRUG'), (14, 20, 'STRENGTH'), (55, 61, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "multivitamins 1 TAB PO DAILY RX* multivitamins 1 t..." with entities "[(0, 13, 'DRUG'), (14, 15, 'STRENGTH'), (49, 55, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "clonidine 0.1 mg/24 hr Patch Weekly Sig: One (1) P..." with entities "[(0, 9, 'DRUG'), (10, 16, 'STRENGTH'), (23, 28, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "cyanocobalamin 1000 mcg Tablet Sig: One (1) Tablet..." with entities "[(0, 14, 'DRUG'), (15, 16, 'STRENGTH'), (24, 30, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "hydromorphone (Dilaudid) 2 mg PO Q4H:PRN Pain RX *..." with entities "[(0, 13, 'DRUG'), (25, 29, 'STRENGTH'), (91, 97, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nafcillin in D2. 4W 2 g/100 mL Piggyback Sig: Two ..." with entities "[(0, 12, 'DRUG'), (14, 15, 'STRENGTH'), (77, 90, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "na-hydrocodone-4-50 mcg/dose Disk with Device Sig:..." with entities "[(0, 2, 'DRUG'), (15, 23, 'STRENGTH'), (29, 45, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "docusate sodium 100 mg PO BID RX *docusate sodium ..." with entities "[(0, 15, 'DRUG'), (16, 22, 'STRENGTH'), (59, 66, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient [**Month/Day/Year **] Work Please check..." with entities "[(0, 10, 'DRUG'), (56, 58, 'STRENGTH')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D-3 400 unit Tablet Sig: One (1) Tablet PO..." with entities "[(0, 9, 'DRUG'), (10, 11, 'STRENGTH'), (21, 27, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "latanoprost 0.005 % Drops Sig: One (1) Drop Ophtha..." with entities "[(0, 11, 'DRUG'), (12, 17, 'STRENGTH'), (81, 88, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "torsemide 100 mg PO DAILY Hold for SBP <90 RX *tor..." with entities "[(0, 9, 'DRUG'), (10, 16, 'STRENGTH'), (66, 72, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "levothyroxine 100 mcg PO DAILY RX* levothyroxine 1..." with entities "[(0, 13, 'DRUG'), (14, 21, 'STRENGTH'), (57, 63, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "tamsulosin 0.4 mg PO HS RX* tamsulosin 0.4 mg 1 ca..." with entities "[(0, 10, 'DRUG'), (11, 17, 'STRENGTH'), (48, 55, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "insulin Syringes Low dose U-100 syringes 25-26 gau..." with entities "[(0, 16, 'DRUG'), (28, 31, 'STRENGTH')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "clonidine 0.3 mg/24 hr Patch Weekly Sig: One (1) P..." with entities "[(0, 9, 'DRUG'), (10, 16, 'STRENGTH'), (23, 28, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 5 mg Tablet Sig: One (1) Tablet PO DAIL..." with entities "[(0, 10, 'DRUG'), (11, 15, 'STRENGTH'), (16, 22, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amlodipine 5 mg PO DAILY RX* amlodipine 5 mg 1 tab..." with entities "[(0, 10, 'DRUG'), (11, 15, 'STRENGTH'), (47, 53, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 60 mg PO DAILY Duration: 2 Days Tapered..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (96, 102, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acetaminophen 650 mg PO Q6H RX* acetaminophen 500 ..." with entities "[(0, 13, 'DRUG'), (14, 20, 'STRENGTH'), (55, 61, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acetaminophen 650 mg PO Q6H RX* acetaminophen 325 ..." with entities "[(0, 13, 'DRUG'), (14, 20, 'STRENGTH'), (55, 61, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "tamsulosin 0.4 mg PO HS RX *tamsulosin 0.4 mg 1 ca..." with entities "[(0, 10, 'DRUG'), (11, 17, 'STRENGTH'), (48, 55, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amlodipine 5 mg Tablet Sig: Two (2) Tablet PO DAIL..." with entities "[(0, 10, 'DRUG'), (11, 15, 'STRENGTH'), (16, 22, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "pantoprazole sodium 40 mg Tablet, Delayed Release ..." with entities "[(0, 19, 'DRUG'), (20, 25, 'STRENGTH'), (26, 32, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "furosemide 40 mg Tablet Sig: One (1) Tablet PO DAI..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (17, 23, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "pantoprazole 40 mg Tablet, Delayed Release (E.C.) ..." with entities "[(0, 12, 'DRUG'), (13, 18, 'STRENGTH'), (19, 25, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin B-12 1,000 mcg Tablet Sig: One (1) Tablet ..." with entities "[(0, 9, 'DRUG'), (10, 12, 'STRENGTH'), (23, 29, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "novolin 70/30 InnoLet 100 unit/mL (70-30) Insulin ..." with entities "[(0, 7, 'DRUG'), (8, 10, 'STRENGTH'), (50, 53, 'FO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "pantoprazole 40 mg PO Q12H RX *pantoprazole 40 mg ..." with entities "[(0, 12, 'DRUG'), (13, 18, 'STRENGTH'), (52, 58, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient lab Work Patient will require once week..." with entities "[(0, 14, 'DRUG'), (63, 64, 'STRENGTH')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D2 50.000 unit Tablet Sig: One (1) Tablet ..." with entities "[(0, 9, 'DRUG'), (11, 17, 'STRENGTH'), (23, 29, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acetaminophen 325-650 mg PO Q6H:PRN pain RX *aceta..." with entities "[(0, 13, 'DRUG'), (14, 24, 'STRENGTH'), (68, 74, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acetaminophen 650 mg PO Q4H RX* acetaminophen 500 ..." with entities "[(0, 13, 'DRUG'), (14, 20, 'STRENGTH'), (55, 61, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acetaminophen 650 mg PO Q4H RX* acetaminophen 325 ..." with entities "[(0, 13, 'DRUG'), (14, 20, 'STRENGTH'), (55, 61, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "multivitamins 1 TAB PO DAILY RX* multivitamin tabl..." with entities "[(0, 13, 'DRUG'), (14, 15, 'STRENGTH'), (46, 52, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "montelukast sodium 10 mg PO DAILY RX *Singulair 10..." with entities "[(0, 18, 'DRUG'), (19, 24, 'STRENGTH'), (56, 62, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "cyanocobalamin (vitamin B-12) 1,000 mcg Tablet Sig..." with entities "[(0, 14, 'DRUG'), (26, 28, 'STRENGTH'), (40, 46, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "docusate sodium-100 mg Capsule Sig: One (1) Capsul..." with entities "[(0, 15, 'DRUG'), (16, 22, 'STRENGTH'), (23, 30, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nafcillin in D2.4W 2 g/100 mL Piggyback Sig: Two (..." with entities "[(0, 12, 'DRUG'), (14, 15, 'STRENGTH'), (77, 90, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nafcillin in D2.4W 2 gram/100 mL Piggyback [**Tele..." with entities "[(0, 12, 'DRUG'), (14, 15, 'STRENGTH'), (100, 113,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "tamsulosin 0.4 mg PO DAILY RX *tamsulosin 0.4 mg 1..." with entities "[(0, 10, 'DRUG'), (11, 17, 'STRENGTH'), (51, 58, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "duoneb 0.5 mg-3 mg(2.5 mg base)/3 mL Solution for ..." with entities "[(0, 6, 'DRUG'), (7, 13, 'STRENGTH'), (37, 45, 'FO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nafcillin in D2. 4W 2 g/100 mL Piggyback Sig: One ..." with entities "[(0, 12, 'DRUG'), (14, 15, 'STRENGTH'), (84, 91, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "mycophenolate mofetil 250 mg Capsule [**Hospital1 ..." with entities "[(0, 21, 'DRUG'), (22, 28, 'STRENGTH'), (29, 36, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 20 mg PO DAILY Duration: 2 Days Tapered..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (86, 92, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amlodipine 10 mg PO once a day. Disp:*30 Tablet(s)..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (41, 47, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D2 50,000 unit Capsule Sig: One (1) Capsul..." with entities "[(0, 9, 'DRUG'), (11, 17, 'STRENGTH'), (23, 30, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amoxicillin 500 mg PO Q8H RX *amoxicillin 500 mg 1..." with entities "[(0, 11, 'DRUG'), (12, 18, 'STRENGTH'), (51, 57, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "levothyroxine 100 mcg PO DAILY RX* levothyroxine 5..." with entities "[(0, 13, 'DRUG'), (14, 21, 'STRENGTH'), (56, 62, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D-3 1,000 unit Tablet, Chewable Sig: One (..." with entities "[(0, 9, 'DRUG'), (10, 11, 'STRENGTH'), (23, 29, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ciprofloxacin hcl 500 mg PO Q12H Duration: 7 Days ..." with entities "[(0, 17, 'DRUG'), (18, 24, 'STRENGTH'), (85, 91, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "metolazone 2.5 mg Tablet Sig: One (1) Tablet PO DA..." with entities "[(0, 10, 'DRUG'), (11, 17, 'STRENGTH'), (18, 24, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "sertraline 50 mg Tablet Sig: Five (5) Tablet PO DA..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (17, 23, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "insulin syringe-needle U-100 1 mL 26 x [**2-14**] ..." with entities "[(0, 15, 'DRUG'), (25, 28, 'STRENGTH'), (100, 103,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "bisacodyl 5 mg Tablet, Delayed Release (E.C.) Sig:..." with entities "[(0, 9, 'DRUG'), (10, 14, 'STRENGTH'), (15, 21, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
# ...
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "latanoprost 0.005 % Drops Sig: One (1) Drop Ophtha..." with entities "[(0, 11, 'DRUG'), (12, 17, 'STRENGTH'), (81, 87, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "levothyroxine 100 mcg PO DAILY RX* levothyroxine 1..." with entities "[(0, 13, 'DRUG'), (14, 21, 'STRENGTH'), (57, 63, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "hydralazine 75 mg PO Q8H please hold for SBP <100 ..." with entities "[(0, 11, 'DRUG'), (12, 17, 'STRENGTH'), (76, 82, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 60 mg PO DAILY Duration: 2 Days Tapered..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (96, 102, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D2 50,000 unit Capsule Sig: One (1) Capsul..." with entities "[(0, 9, 'DRUG'), (11, 17, 'STRENGTH'), (23, 30, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "insulin syringe-needle U-100 1 mL 26 x [**2-14**] ..." with entities "[(0, 15, 'DRUG'), (25, 28, 'STRENGTH'), (100, 103,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "hydromorphone (Dilaudid) 2 mg PO Q4H:PRN Pain RX *..." with entities "[(0, 13, 'DRUG'), (25, 29, 'STRENGTH'), (91, 97, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "metolazone 2.5 mg Tablet Sig: One (1) Tablet PO DA..." with entities "[(0, 10, 'DRUG'), (11, 17, 'STRENGTH'), (18, 24, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amlodipine 5 mg Tablet Sig: Two (2) Tablet PO DAIL..." with entities "[(0, 10, 'DRUG'), (11, 15, 'STRENGTH'), (16, 22, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "voriconazole 200 mg PO Q12H RX *voriconazole 200 m..." with entities "[(0, 12, 'DRUG'), (13, 19, 'STRENGTH'), (54, 60, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D3  Oral
# " with entities "[(0, 9, 'DRUG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amoxicillin 500 mg PO Q8H RX *amoxicillin 500 mg 1..." with entities "[(0, 11, 'DRUG'), (12, 18, 'STRENGTH'), (51, 57, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "levothyroxine 100 mcg PO DAILY RX* levothyroxine 2..." with entities "[(0, 13, 'DRUG'), (14, 21, 'STRENGTH'), (56, 62, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nafcillin in D2.4W 2 gram/100 mL Piggyback [**Tele..." with entities "[(0, 12, 'DRUG'), (14, 15, 'STRENGTH'), (100, 113,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acetaminophen 325-650 mg PO Q6H:PRN pain RX *aceta..." with entities "[(0, 13, 'DRUG'), (14, 24, 'STRENGTH'), (68, 74, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "sertraline 50 mg Tablet Sig: Five (5) Tablet PO DA..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (17, 23, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient [**Name (NI) **] Work PT, PTT, INR, Che..." with entities "[(0, 10, 'DRUG'), (52, 53, 'STRENGTH'), (70, 82, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "mycophenolate mofetil 250 mg Capsule [**Hospital1 ..." with entities "[(0, 21, 'DRUG'), (22, 28, 'STRENGTH'), (29, 36, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "acyclovir 400 mg PO Q8H RX *acyclovir 400 mg 1 tab..." with entities "[(0, 9, 'DRUG'), (10, 16, 'STRENGTH'), (47, 53, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "metoprolol tartrate 12.5 mg PO BID hold for SBP < ..." with entities "[(0, 19, 'DRUG'), (20, 27, 'STRENGTH'), (108, 114,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin D-3 400 unit Tablet [**Hospital1 **]: One ..." with entities "[(0, 9, 'DRUG'), (10, 11, 'STRENGTH'), (21, 27, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nafcillin in D2. 4W 2 gram/100 mL Piggyback [** Ho..." with entities "[(0, 12, 'DRUG'), (14, 15, 'STRENGTH'), (87, 100, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "omeprazole 20 mg PO BID RX *omeprazole 20 mg 1 cap..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (47, 54, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient lab Work Patient will require once week..." with entities "[(0, 14, 'DRUG'), (63, 64, 'STRENGTH')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "furosemide 40 mg Tablet Sig: One (1) Tablet PO DAI..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (17, 23, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "outpatient lab Work Weekly Chem-7, CBC with DIFF, ..." with entities "[(0, 14, 'DRUG'), (32, 33, 'STRENGTH'), (20, 26, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "amlodipine 5 mg Tablet Sig: One (1) Tablet PO DAIL..." with entities "[(0, 10, 'DRUG'), (11, 15, 'STRENGTH'), (16, 22, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "torsemide 100 mg PO DAILY Hold for SBP <90 RX *tor..." with entities "[(0, 9, 'DRUG'), (10, 16, 'STRENGTH'), (66, 72, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "clopidogrel 75 mg PO DAILY RX *clopidogrel 75 mg 1..." with entities "[(0, 11, 'DRUG'), (12, 17, 'STRENGTH'), (51, 57, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "vitamin B-12 1,000 mcg Tablet Sig: One (1) Tablet ..." with entities "[(0, 9, 'DRUG'), (10, 12, 'STRENGTH'), (23, 29, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ciprofloxacin hcl 500 mg PO Q12H Duration: 7 Days ..." with entities "[(0, 17, 'DRUG'), (18, 24, 'STRENGTH'), (85, 91, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "montelukast sodium 10 mg PO DAILY RX *Singulair 10..." with entities "[(0, 18, 'DRUG'), (19, 24, 'STRENGTH'), (56, 62, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nafcillin in D2.4W 2 g/100 mL Piggyback Sig: Two (..." with entities "[(0, 12, 'DRUG'), (14, 15, 'STRENGTH'), (77, 90, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "prednisone 20 mg PO DAILY Duration: 2 Days Tapered..." with entities "[(0, 10, 'DRUG'), (11, 16, 'STRENGTH'), (86, 92, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "novolin 70/30 InnoLet 100 unit/mL (70-30) Insulin ..." with entities "[(0, 7, 'DRUG'), (8, 10, 'STRENGTH'), (50, 53, 'FO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#
#  10%|█         | 1/10 [08:22<1:15:20, 502.25s/it]
#  20%|██        | 2/10 [17:45<1:11:46, 538.35s/it]
#  30%|███       | 3/10 [26:46<1:02:56, 539.54s/it]
#  40%|████      | 4/10 [35:33<53:26, 534.36s/it]
#  50%|█████     | 5/10 [44:14<44:07, 529.46s/it]
#  60%|██████    | 6/10 [52:51<35:01, 525.33s/it]
#  70%|███████   | 7/10 [1:01:30<26:09, 523.25s/it]
#  80%|████████  | 8/10 [1:10:11<17:25, 522.58s/it]
#  90%|█████████ | 9/10 [1:18:50<08:41, 521.62s/it]

# %%
with open("drive/MyDrive/SynDa_Health/DatasetAnalysis/Generations/dfsSynthetic.pkl", "rb") as pickle_file:
    loaded_dfs = pickle.load(pickle_file)

# %%
loaded_dfs
[i*100 for i in range(1, 6)]
# Out:
#            Precision    Recall  F1 Score
# FREQUENCY   0.905547  0.927091  0.916193
# FORM        0.990735  0.991347  0.991041
# ROUTE       0.988322  0.998758  0.993513
# DRUG        0.990191  0.995071  0.992625
# STRENGTH    0.886115  0.942478  0.913428
# overall     0.952387  0.972566  0.962370

# %%
loaded_dfs[0]['F1 Score']['overall']
# Out:
# 0.962370478094892
